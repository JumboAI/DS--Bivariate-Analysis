# %%
import pandas as pd
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# Step 1 to check got missing value 
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.info()
##notice got missing value in salary column( numerical)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset.isnull().sum()
#notice got missing value in all the 7 numerical column
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# #Answer Q1 & Q4 ."salary" The position was not filled, which is the reason for the missing values I use fillna to replace the value with 0
# "sl_no"  I decided to exclude the entire column due to irrelevant info

# %%
dataset["salary"].fillna(0,inplace=True)
dataset.drop('sl_no',axis=1, inplace=True)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# #Answer Question 2 -counts the number of rows where the 'status' is 'Not Placed

# %%
not_placed = dataset[dataset['status'] == 'Not Placed'].shape[0]
print(not_placed)
# Out:
# 67

# %%
placed = dataset[dataset['status'] == 'Placed'].shape[0]
print(placed)
# Out:
# 148

# %%
148+67
# Out:
# 215

# %%
#for the rest will use central tendency  value, Wrong dataset not applicable 
dataset["ssc_p"].fillna(dataset["ssc_p"].mean(),inplace=True)
dataset["hsc_p"].fillna(dataset["hsc_p"].mean(),inplace=True)
dataset["degree_p"].fillna(dataset["degree_p"].mean(),inplace=True)
dataset["etest_p"].fillna(dataset["etest_p"].mean(),inplace=True)
dataset["mba_p"].fillna(dataset["mba_p"].mean(),inplace=True)

# %%
dataset

# %%
dataset.info()

# %%
dataset.isnull().sum()

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columName in (dataset.columns):
            #print(columName)
            if (dataset[columName].dtype=='O'):
                #print("qual")
                qual.append(columName)
            else:
                #print("quan")
                quan.append(columName)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
dataset["ssc_p"].mean()

# %%
dataset["ssc_p"].median()

# %%
dataset["ssc_p"].mode()[0]

# %%
dataset.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
dash=pd.DataFrame(index=["Mean","Median","Mode"], columns=quan)

# %%
dash
# Out:
#        ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN      NaN     NaN   NaN    NaN

# %%
dash["salary"]["Median"]=0

# %%
dash
# Out:
#        ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN      NaN     NaN   NaN      0
# Mode     NaN   NaN      NaN     NaN   NaN    NaN

# %%
dash=pd.DataFrame(index=["Mean","Median","Mode"], columns=quan)
for columName in quan:
    dash[columName]["Mean"]=dataset[columName].mean()
    dash[columName]["Median"]=dataset[columName].median()
    dash[columName]["Mode"]=dataset[columName].mode()[0]

# %%
dash
# Out:
#             ssc_p      hsc_p   degree_p    etest_p      mba_p         salary
# Mean    67.303395  66.333163  66.370186  72.100558  62.278186  198702.325581
# Median       67.0       65.0       66.0       71.0       62.0       240000.0
# Mode         62.0       63.0       65.0       60.0       56.7            0.0

# %%
#Q4-The relation between mba and salary -on average candidates in the dataset had a mean mba_p percentage of approximately 
#62.14% and mean salary 240000 and the overall distribution of salary level with some candidates earning higher salaries

# %%
dataset['salary'].max()
# Out:
# 940000.0

# %%
#Q5- specializaton with min salary

# %%
min_salary_by_specialization = dataset.groupby('specialisation')['salary'].median()
print("Specialization with the min salary:")
print(min_salary_by_specialization)
# Out:
# Specialization with the min salary:
# specialisation
# Mkt&Fin    250000.0
# Mkt&HR     210000.0
# Name: salary, dtype: float64

# %%
#Q6 How many of them getting above 500000 salary

# %%
above_500000 = dataset[dataset['salary'] > 500000].shape[0]
print("Number of individuals with salaries above 500000:", above_500000)
# Out:
# Number of individuals with salaries above 500000: 3

# %% [markdown]
# #7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%. (Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"], dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#The one-way ANOVA is used to assess whether there are statistically significant differences among these groups.
#With a p-value 4.672547689133573e-21 is less then significance level 0.05, 
we reject the null hypothesis and we can conclude there is significant differences between these group.

# %% [markdown]
# 8)Test the similarity between the degree_t (Sci&Tech) and specialisation (Mkt&HR)
# with respect to salary  at significance level of 5%.(Make decision using Hypothesis Testing)
#
# #use Independant Sample -Unpaired T Test(different group but same condition)

# %%
#dataset[dataset["degree_t"]=='Sci&Tech']['salary']
dataset[dataset["degree_t"]=='Sci&Tech']
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00  Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48  Sci&Tech
# 3        M  56.00  Central  52.00  Central   Science     52.00  Sci&Tech
# 5        M  55.00   Others  49.80   Others   Science     67.25  Sci&Tech
# 7        M  82.00  Central  64.00  Central   Science     66.00  Sci&Tech
# 22       F  69.80   Others  60.80   Others   Science     72.23  Sci&Tech
# 23       F  77.40   Others  60.00   Others   Science     64.74  Sci&Tech
# 24       M  76.50   Others  97.70   Others   Science     78.86  Sci&Tech
# 31       F  67.00  Central  53.00  Central   Science     65.00  Sci&Tech
# 37       F  79.00  Central  76.00  Central   Science     65.60  Sci&Tech
# 39       M  81.00   Others  68.00   Others   Science     64.00  Sci&Tech
# 45       F  76.00  Central  64.00  Central   Science     72.00  Sci&Tech
# ...

# %%
dataset[dataset["specialisation"]=='Mkt&HR']
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 10       M  58.00  Central  61.00  Central  Commerce     60.00  Comm&Mgmt
# 12       F  47.00  Central  55.00   Others   Science     65.00  Comm&Mgmt
# 14       M  62.00  Central  47.00  Central  Commerce     50.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 202      M  70.00  Central  63.00  Central   Science     66.00   Sci&Tech
# 203      M  55.68   Others  61.33   Others  Commerce     56.87  Comm&Mgmt
# 208      F  43.00  Central  60.00   Others   Science     65.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
degree_t=dataset[dataset["degree_t"]=="Sci&Tech"]['salary']
specialisation=dataset[dataset["specialisation"]=="Mkt&HR"]['salary']
#print(degree_t,specialisation)
ttest_ind(degree_t,specialisation)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %%
#TTest used to assess whether there are statistically significant similarity among these groups.
#With a p-value 0.00789 is less then significance level 0.05, 
we reject the null hypothesis and we can conclude there is significant similarity  between these group.

# %%
dash=pd.DataFrame(index=["Mean","Median","Mode","Var","Std"] ,columns=quan)
for columName in quan:
    dash[columName]["Mean"]=dataset[columName].mean()
    dash[columName]["Median"]=dataset[columName].median()
    dash[columName]["Mode"]=dataset[columName].mode()[0]
    dash[columName]["Var"]=dataset[columName].var()
    dash[columName]["Std"]=dataset[columName].std()

# %%
dash

# %% [markdown]
# #9)Convert the normal distribution to standard normal distribution for salary column

# %%
dataset['salary'].var()

# %%
dataset['salary'].std()

# %%
dataset.salary.describe()
# Out:
# count       215.000000
# mean     198702.325581
# std      154780.926716
# min           0.000000
# 25%           0.000000
# 50%      240000.000000
# 75%      282500.000000
# max      940000.000000
# Name: salary, dtype: float64

# %%
import seaborn as sns
sns.histplot(dataset.salary, kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
def stdNBgraph(dataset):
    #Covert to Standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    
    values=[i for i in dataset]
    z_score=[((j-mean)/std) for j in values]
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_6832\110226590.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %% [markdown]
# #10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color ='black')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    #generate a sample
    sample=dataset
    #calculate parameters
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f, Standard Deviation=%3.f'%(sample_mean,sample_std))
    #define the distribution
    dist=norm(sample_mean,sample_std)
    #sample probabilities for a range of outcomes
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_6832\494452129.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color ='black')
# Mean=198702.326, Standard Deviation=154781
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %%
#11)Test the similarity between the degree_t(Sci&Tech) with respect to etest_p and mba_p at significance level of 5%.
(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
SciTech=dataset[dataset["degree_t"]=="Sci&Tech"]['etest_p']
SciTech1=dataset[dataset["degree_t"]=="Sci&Tech"]['mba_p']
#print sep
ttest_rel(SciTech,SciTech1)

# %%
the p-value (5.517920600505392e-06) is much smaller than 0.05. 
Therefore, we would reject the null hypothesis. 
There is a significant difference between the mean etest_p and mba_p scores for students in the Sci&Tech degree program

# %%
#Q12 and Q13 related unable to proceed 
#due to a recent version update that has rendered the code inoperable-3/13/23
